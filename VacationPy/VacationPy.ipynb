# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
file_path = os.path.join("..","output_data", "cities.csv")
weather_data = pd.read_csv(file_path)
weather_data.set_index(["City_ID"], inplace=True)
weather_data.head()
# Out:
#                    City    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               Aksarka  66.56  67.80     44.13        88         100
# 1                Caniço  32.63 -16.85     68.00        72          20
# 2                Teshie   5.58  -0.11     75.20        94          75
# 3        Ribeira Grande  38.52 -28.70     70.50        78          57
# 4            Bredasdorp -34.53  20.04     44.60        93          30
#
#          Wind Speed Country        Date
# City_ID
# 0             13.78      RU  1600396302
# 1              5.82      PT  1600396302
# 2             10.29      GH  1600396303
# 3             16.40      PT  1600396303
# 4              1.12      ZA  1600396011

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
print(g_key)
# Out:
# AIzaSyCSel_7zt8qso61wDuTA0oEsW4lgA_9BpI

# %%
# access maps with unique API key
gmaps.configure(api_key=g_key)
# create dataframe with lat, lng and Humidity
locations = weather_data[["Lat","Lng"]]
humidity = weather_data["Humidity"]

# %%
# create intial gmap figure
fig = gmaps.figure()
# add heatmap layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=100, point_radius=0.9)
# add heatmap layer to figure
fig.add_layer(heatmap_layer)
# Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_weather = weather_data[(weather_data["Humidity"] > 70) & (weather_data["Humidity"] <= 75)]
ideal_weather = ideal_weather.dropna()
ideal_weather
# Out:
#                             City    Lat     Lng  Max Temp  Humidity  \
# City_ID
# 1                         Caniço  32.63  -16.85     68.00        72
# 5                         Anadyr  64.75  177.48     44.60        75
# 20                    Butaritari   3.07  172.79     82.27        73
# 29               Plettenberg Bay -34.05   23.37     54.99        72
# 39                        Palana  59.12  159.97     45.68        74
# 57                   East London -33.02   27.91     59.63        74
# 73                  Ponta do Sol  32.67  -17.10     68.00        72
# 90                      Cardston  49.20 -113.30     57.20        71
# 104                   Kiryat Gat  31.61   34.76     78.01        73
# 106                     Ratodero  27.80   68.29     84.20        74
# 140                Saint Anthony  45.02  -93.22     51.80        75
# 142                        Roald  62.58    6.13     59.00        72
# 150                      Kavieng  -2.57  150.80     84.18        74
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# store ideal_weather dataframe as hotel_df
hotel_df = ideal_weather.astype(str)
# add empty Hotel Name column to dataframe
hotel_df["Hotel Name"] = ""

# set base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

# parameter variables hotels within 5000 meters
for index,row in hotel_df.iterrows():
    try:
        location = row[str("Lat")] + "," + row[str("Lng")]
        request_url = base_url + "location=" + location + "&radius=5000" + "&type=lodging" + "&key=" + g_key
        response = requests.get(request_url).json()
        hotel_name = response["results"][0]["name"]
        row["Hotel Name"] = hotel_name
    except IndexError:
        row["Hotel Name"] = "**No hotel within 5000 meters**"
hotel_df.head()
# Out:
#                     City     Lat     Lng Max Temp Humidity Cloudiness  \
# City_ID
# 1                 Caniço   32.63  -16.85     68.0       72         20
# 5                 Anadyr   64.75  177.48     44.6       75         75
# 20            Butaritari    3.07  172.79    82.27       73         96
# 29       Plettenberg Bay  -34.05   23.37    54.99       72          0
# 39                Palana   59.12  159.97    45.68       74          0
#
#         Wind Speed Country        Date  \
# City_ID
# 1             5.82      PT  1600396302
# 5            11.18      RU  1600396304
# 20           12.19      KI  1600396307
# 29            3.44      ZA  1600396309
# 39            8.43      RU  1600396312
#
#                                            Hotel Name
# City_ID
# 1        Quinta Splendida Wellness & Botanical Garden
# 5                                 Гостиница "Анадырь"
# 20                                 Isles Sunset Lodge
# 29                                   Thanda Vista B&B
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
locations = locations.astype(float)
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
