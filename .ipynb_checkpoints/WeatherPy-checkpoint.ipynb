# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Links:
# python library: https://pypi.python.org/pypi/citipy
#
# Weather api: https://openweathermap.org/api

# %%
import random
from citipy import citipy
import requests
import json
from pprint import pprint
from api_keys import weather_api_key
import pandas as pd
import os
import matplotlib.pyplot as plt
import datetime
from scipy.stats import linregress

# %% [markdown]
# ## Generate Cities List

# %%
# Generate cities lists
cities = []

# Loop to create randon latitudes and longitudes
for i in range(0,1500):
    lat = round(random.uniform(-90,90),2)
    lng = round(random.uniform(-180,180),2)
    # Use citipy to find the nearest city to the (lat, lng)
    city = citipy.nearest_city(lat, lng)
    # Use citipy to return the name of the neareat city
    city_name = city.city_name
    # Append city name to city list
    cities.append(city_name)
# Remove any duplicates in the cities list
cities = list(dict.fromkeys(cities))
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build base URL for API call
weather_response = []
base_url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weather_api_key + "&units=imperial" + "&q="
counter = 0

#create lists empty lists to hold desired data
city_name = []
latitude = []
longitude = []
temp_max = []
humidity = []
clouds = []
wind_speed = []
date = []
country = []

# API call loop
for citi in cities:
    query_url = base_url + citi
    try:
        response = requests.get(query_url).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        temp_max.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        clouds.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record | {citi}")
    except:
        print(f"City not found | {citi}")
# Out:
# Processing Record | neiafu
# Processing Record | kupang
# Processing Record | albany
# Processing Record | arraial do cabo
# City not found | gurskoye
# Processing Record | east london
# Processing Record | castro
# Processing Record | bambous virieux
# Processing Record | nanortalik
# Processing Record | thompson
# City not found | barentsburg
# City not found | guajara-mirim
# Processing Record | hamilton
# Processing Record | port alfred
# Processing Record | minudasht
# Processing Record | atuona
# Processing Record | bluff
# Processing Record | san vicente
# Processing Record | cape town
# Processing Record | ushuaia
# Processing Record | lebu
# Processing Record | hermanus
# Processing Record | avarua
# City not found | nizhneyansk
# Processing Record | hobart
# Processing Record | patea
# Processing Record | tuatapere
# Processing Record | mapimi
# City not found | ondorhaan
# Processing Record | rikitea
# Processing Record | ambon
# Processing Record | kodiak
# Processing Record | jamestown
# City not found | kamenskoye
# Processing Record | lompoc
# Processing Record | ulaangom
# Processing Record | hilo
# City not found | samusu
# Processing Record | pimentel
# Processing Record | naron
# Processing Record | saskylakh
# Processing Record | coihaique
# Processing Record | murdochville
# Processing Record | pontianak
# Processing Record | rawson
# Processing Record | esperance
# Processing Record | locri
# Processing Record | mataura
# Processing Record | butaritari
# City not found | umzimvubu
# Processing Record | airai
# Processing Record | busselton
# Processing Record | vaini
# Processing Record | ciudad bolivar
# Processing Record | qaanaaq
# Processing Record | nova venecia
# Processing Record | barrow
# Processing Record | staszow
# Processing Record | ribeira grande
# Processing Record | haines junction
# Processing Record | bykov
# Processing Record | baturaja
# Processing Record | cabo san lucas
# Processing Record | presidente epitacio
# City not found | illoqqortoormiut
# Processing Record | oktyabrskoye
# Processing Record | oktyabrskiy
# Processing Record | erzin
# Processing Record | zhigansk
# Processing Record | saint-philippe
# Processing Record | mount gambier
# Processing Record | sitka
# Processing Record | chuy
# Processing Record | los llanos de aridane
# Processing Record | limbang
# Processing Record | bida
# Processing Record | fort-shevchenko
# Processing Record | san patricio
# Processing Record | petropavlovsk-kamchatskiy
# Processing Record | punta arenas
# Processing Record | talnakh
# Processing Record | alakurtti
# City not found | amderma
# Processing Record | ilulissat
# Processing Record | tasiilaq
# Processing Record | piacabucu
# Processing Record | sydney
# Processing Record | sioux lookout
# Processing Record | port lincoln
# Processing Record | rakiv lis
# Processing Record | mar del plata
# Processing Record | dingle
# Processing Record | nkayi
# Processing Record | sao gabriel da cachoeira
# Processing Record | chickasha
# Processing Record | cheremukhovo
# Processing Record | assiniboia
# City not found | tokzar
# City not found | taolanaro
# City not found | kawana waters
# Processing Record | kapaa
# Processing Record | caravelas
# Processing Record | bredasdorp
# Processing Record | soe
# Processing Record | nikolskoye
# Processing Record | sakakah
# Processing Record | price
# Processing Record | coquimbo
# Processing Record | mehamn
# Processing Record | saint george
# Processing Record | inverell
# Processing Record | paita
# Processing Record | esna
# Processing Record | geraldton
# Processing Record | waingapu
# Processing Record | svetlogorsk
# Processing Record | tuktoyaktuk
# Processing Record | yaring
# Processing Record | clyde river
# City not found | belushya guba
# Processing Record | honningsvag
# Processing Record | georgetown
# City not found | tsihombe
# Processing Record | bengkulu
# Processing Record | fairbanks
# Processing Record | chokurdakh
# Processing Record | balurghat
# Processing Record | rio grande
# Processing Record | ishikawa
# Processing Record | yumen
# Processing Record | mokolo
# Processing Record | gat
# Processing Record | mollendo
# Processing Record | samarai
# Processing Record | pevek
# Processing Record | tezu
# Processing Record | ipilan
# Processing Record | constitucion
# Processing Record | dire
# Processing Record | khatanga
# Processing Record | acapulco
# Processing Record | nizwa
# Processing Record | victoria
# Processing Record | dikson
# Processing Record | kavieng
# City not found | ust-kamchatsk
# Processing Record | puerto ayora
# Processing Record | lasa
# Processing Record | quelimane
# Processing Record | ankazoabo
# Processing Record | lavrentiya
# Processing Record | beaverlodge
# City not found | sentyabrskiy
# Processing Record | portland
# Processing Record | vanimo
# Processing Record | cayenne
# Processing Record | new norfolk
# Processing Record | norman wells
# City not found | tarhunah
# Processing Record | hithadhoo
# Processing Record | dali
# Processing Record | toumodi
# Processing Record | camacupa
# Processing Record | saldanha
# Processing Record | shimoda
# Processing Record | warri
# Processing Record | cherskiy
# Processing Record | mongo
# Processing Record | lithakia
# Processing Record | kamenka
# Processing Record | ambunti
# Processing Record | ostrovnoy
# Processing Record | rockport
# Processing Record | daman
# Processing Record | villefontaine
# Processing Record | provideniya
# Processing Record | ternate
# Processing Record | grenville
# Processing Record | togur
# Processing Record | lorengau
# Processing Record | nizhnedevitsk
# Processing Record | asau
# Processing Record | pangnirtung
# City not found | palabuhanratu
# Processing Record | mitsamiouli
# Processing Record | vostok
# Processing Record | nicolas de pierola
# Processing Record | flinders
# Processing Record | lagoa
# Processing Record | tateyama
# Processing Record | sisimiut
# Processing Record | palmer
# Processing Record | mosquera
# Processing Record | vuktyl
# Processing Record | turbat
# Processing Record | limon
# Processing Record | berdsk
# Processing Record | kingaroy
# Processing Record | katobu
# Processing Record | pozo colorado
# Processing Record | leningradskiy
# Processing Record | ojinaga
# Processing Record | kourou
# Processing Record | chanika
# Processing Record | hokitika
# Processing Record | mpanda
# Processing Record | bonfim
# Processing Record | westport
# City not found | cape elizabeth
# Processing Record | san quintin
# Processing Record | salima
# City not found | vaitupu
# City not found | marcona
# Processing Record | pangai
# Processing Record | fare
# Processing Record | borogontsy
# Processing Record | faanui
# Processing Record | takahagi
# Processing Record | zhangzhou
# Processing Record | waziers
# Processing Record | sierra vista
# Processing Record | omsukchan
# Processing Record | primorsk
# Processing Record | severo-kurilsk
# Processing Record | bethel
# Processing Record | gravdal
# City not found | chagda
# Processing Record | vila
# Processing Record | panguna
# Processing Record | ndele
# Processing Record | jadu
# Processing Record | vila velha
# Processing Record | thyboron
# Processing Record | port elizabeth
# Processing Record | plast
# Processing Record | union
# Processing Record | matagami
# Processing Record | sao filipe
# Processing Record | tiksi
# Processing Record | yeppoon
# Processing Record | isangel
# Processing Record | ponta delgada
# Processing Record | luderitz
# Processing Record | cabedelo
# Processing Record | colac
# Processing Record | diamantino
# Processing Record | santa cruz del sur
# Processing Record | oistins
# City not found | ciras
# Processing Record | kursk
# Processing Record | saravan
# Processing Record | mangaratiba
# Processing Record | hofn
# Processing Record | yellowknife
# Processing Record | broken hill
# Processing Record | basoko
# Processing Record | abapo
# Processing Record | marathon
# Processing Record | kuching
# Processing Record | ancud
# Processing Record | alofi
# Processing Record | xinpu
# Processing Record | carnarvon
# Processing Record | vestmanna
# Processing Record | waitara
# Processing Record | vanavara
# Processing Record | shar
# Processing Record | guerrero negro
# Processing Record | praya
# Processing Record | gimli
# Processing Record | bosaso
# Processing Record | yazman
# Processing Record | kahului
# Processing Record | buala
# Processing Record | tautira
# City not found | tidore
# Processing Record | faya
# Processing Record | ponta do sol
# City not found | santa eulalia del rio
# Processing Record | nizhniy odes
# Processing Record | salalah
# Processing Record | praia da vitoria
# Processing Record | fortuna
# Processing Record | zverinogolovskoye
# Processing Record | kaitangata
# Processing Record | pisco
# Processing Record | roebourne
# Processing Record | kisangani
# Processing Record | elko
# Processing Record | matara
# Processing Record | hasaki
# Processing Record | messias
# Processing Record | kaeo
# Processing Record | balakhta
# Processing Record | solhan
# Processing Record | mirabad
# Processing Record | labytnangi
# Processing Record | rio cuarto
# Processing Record | marawi
# Processing Record | ulaanbaatar
# Processing Record | saint-pierre
# Processing Record | beringovskiy
# Processing Record | abha
# Processing Record | baykit
# Processing Record | aklavik
# Processing Record | loten
# Processing Record | tres arroyos
# Processing Record | broome
# City not found | samalaeulu
# Processing Record | barao de melgaco
# Processing Record | susuman
# City not found | karkaralinsk
# Processing Record | perth
# Processing Record | vacaria
# Processing Record | inongo
# Processing Record | aykino
# Processing Record | ketchikan
# Processing Record | severobaykalsk
# Processing Record | gambo
# Processing Record | christchurch
# Processing Record | dicabisagan
# Processing Record | marienburg
# Processing Record | pilar
# Processing Record | kikwit
# Processing Record | mawlaik
# Processing Record | tulsipur
# Processing Record | quimper
# Processing Record | natal
# Processing Record | samana
# Processing Record | port-cartier
# Processing Record | naryan-mar
# Processing Record | mahebourg
# Processing Record | puerto escondido
# City not found | grand river south east
# Processing Record | the valley
# Processing Record | renfrew
# Processing Record | yebaishou
# Processing Record | beipiao
# Processing Record | buraydah
# Processing Record | elizabeth city
# Processing Record | pacific grove
# City not found | mys shmidta
# City not found | khonuu
# Processing Record | kismayo
# Processing Record | san joaquin
# Processing Record | iralaya
# Processing Record | margate
# Processing Record | chisec
# Processing Record | haimen
# Processing Record | kavaratti
# City not found | galgani
# Processing Record | nouadhibou
# Processing Record | tura
# Processing Record | codrington
# Processing Record | clarence town
# Processing Record | kinablangan
# Processing Record | millinocket
# Processing Record | mlalo
# Processing Record | kargil
# Processing Record | aginskoye
# Processing Record | mets masrik
# Processing Record | lufilufi
# Processing Record | sibolga
# Processing Record | hervey bay
# Processing Record | hobyo
# Processing Record | constancia
# Processing Record | ati
# Processing Record | ayan
# Processing Record | bilma
# Processing Record | sabha
# City not found | bolungarvik
# Processing Record | port augusta
# Processing Record | deputatskiy
# Processing Record | dabhol
# Processing Record | marrakesh
# Processing Record | kaura namoda
# Processing Record | naze
# Processing Record | tomatlan
# Processing Record | stornoway
# Processing Record | aktau
# City not found | higuey
# Processing Record | tanout
# Processing Record | celestun
# Processing Record | sola
# Processing Record | manerbio
# Processing Record | aksarka
# Processing Record | manzhouli
# Processing Record | ayr
# Processing Record | cidreira
# Processing Record | plettenberg bay
# Processing Record | emba
# Processing Record | bereda
# Processing Record | darhan
# Processing Record | mana
# Processing Record | tokmak
# Processing Record | bahia blanca
# Processing Record | alugan
# Processing Record | trelew
# Processing Record | iroquois falls
# Processing Record | kushima
# Processing Record | narsaq
# Processing Record | upernavik
# Processing Record | muzhi
# Processing Record | mayskiy
# Processing Record | puerto del rosario
# Processing Record | tefe
# Processing Record | toora-khem
# Processing Record | longyearbyen
# Processing Record | mendeleyevsk
# Processing Record | padang
# Processing Record | peniche
# Processing Record | salym
# Processing Record | leh
# Processing Record | sao sebastiao
# Processing Record | karratha
# Processing Record | raudeberg
# Processing Record | iqaluit
# Processing Record | taoudenni
# Processing Record | afyonkarahisar
# Processing Record | saint-joseph
# Processing Record | oranjemund
# Processing Record | saltillo
# Processing Record | salamiyah
# Processing Record | san cristobal
# Processing Record | labuhan
# Processing Record | katsuura
# Processing Record | mount isa
# Processing Record | jacareacanga
# City not found | bacuit
# Processing Record | cachoeira do sul
# Processing Record | norton
# Processing Record | mezen
# Processing Record | namibe
# City not found | bargal
# Processing Record | meulaboh
# Processing Record | hualmay
# Processing Record | yinchuan
# Processing Record | horqueta
# Processing Record | ferme-neuve
# Processing Record | moose factory
# Processing Record | ravar
# Processing Record | dunedin
# Processing Record | cap malheureux
# Processing Record | goma
# Processing Record | drumheller
# Processing Record | nishihara
# Processing Record | poum
# Processing Record | biak
# Processing Record | huarmey
# Processing Record | thinadhoo
# Processing Record | kiunga
# Processing Record | jining
# Processing Record | ossora
# Processing Record | zandvoort
# Processing Record | jalingo
# Processing Record | laguna
# Processing Record | trairi
# Processing Record | alyangula
# Processing Record | nova olimpia
# Processing Record | sorland
# Processing Record | henties bay
# Processing Record | san policarpo
# Processing Record | dongzhen
# Processing Record | sur
# Processing Record | ritchie
# City not found | sofiysk
# Processing Record | kruisfontein
# Processing Record | srednekolymsk
# Processing Record | san andres
# Processing Record | andros town
# Processing Record | sidhi
# Processing Record | souillac
# Processing Record | iquique
# Processing Record | komsomolskiy
# City not found | kuanshan
# Processing Record | mokhsogollokh
# Processing Record | temerloh
# Processing Record | maseru
# Processing Record | barcelos
# Processing Record | ambilobe
# Processing Record | saint-augustin
# Processing Record | nemuro
# Processing Record | flagstaff
# Processing Record | obigarm
# Processing Record | remanso
# Processing Record | hirara
# Processing Record | adrar
# Processing Record | chicama
# Processing Record | porto santo
# Processing Record | abnub
# Processing Record | songea
# Processing Record | chamba
# Processing Record | kampot
# Processing Record | gizo
# City not found | warqla
# Processing Record | tambovka
# Processing Record | raga
# Processing Record | bolu
# Processing Record | yerbogachen
# Processing Record | tambura
# Processing Record | kembe
# Processing Record | sangolqui
# City not found | yanan
# Processing Record | isla mujeres
# Processing Record | grand forks
# Processing Record | nome
# City not found | achisay
# Processing Record | nueva granada
# Processing Record | high level
# Processing Record | madison heights
# Processing Record | cochrane
# Processing Record | ewa beach
# Processing Record | albertville
# Processing Record | mareeba
# Processing Record | qurayyat
# Processing Record | huangnihe
# Processing Record | kulhudhuffushi
# Processing Record | igarka
# Processing Record | shakawe
# Processing Record | sistranda
# Processing Record | hami
# Processing Record | manor
# Processing Record | akyab
# Processing Record | altay
# City not found | saleaula
# Processing Record | naklo nad notecia
# Processing Record | safaga
# Processing Record | wanaka
# Processing Record | nkhotakota
# Processing Record | torbay
# Processing Record | kigoma
# Processing Record | asyut
# Processing Record | podgornoye
# Processing Record | mahanoro
# Processing Record | qaqortoq
# Processing Record | jasper
# Processing Record | caramay
# Processing Record | moroni
# Processing Record | kyren
# Processing Record | zeya
# Processing Record | todos santos
# Processing Record | itaituba
# Processing Record | kathmandu
# Processing Record | chapais
# City not found | formoso do araguaia
# Processing Record | mayo
# Processing Record | gallup
# Processing Record | macas
# Processing Record | sao joao da barra
# Processing Record | hengyang
# Processing Record | araouane
# Processing Record | tchaourou
# Processing Record | kuito
# Processing Record | dryden
# Processing Record | port hardy
# Processing Record | evensk
# Processing Record | eirunepe
# City not found | karaul
# Processing Record | ilheus
# Processing Record | kibre mengist
# Processing Record | moree
# Processing Record | benguela
# Processing Record | biltine
# Processing Record | grand gaube
# Processing Record | san jeronimo
# Processing Record | velsk
# Processing Record | egvekinot
# Processing Record | bilasipara
# Processing Record | orlik
# Processing Record | filadelfia
# Processing Record | durres
# City not found | aalestrup
# Processing Record | mazyr
# Processing Record | port macquarie
# Processing Record | barreirinhas
# Processing Record | playas
# Processing Record | baruun-urt
# Processing Record | tianpeng
# Processing Record | kushiro
# Processing Record | tukrah
# Processing Record | palu
# Processing Record | abomsa
# Processing Record | urusha
# Processing Record | batagay
# Processing Record | roald
# City not found | rostaq
# Processing Record | kosa
# Processing Record | antanifotsy
# Processing Record | san jose
# Processing Record | yudong
# Processing Record | soller
# Processing Record | nuuk
# Processing Record | port keats
# Processing Record | mugur-aksy
# Processing Record | olinda
# Processing Record | belmonte
# Processing Record | marsa matruh
# Processing Record | belaya gora
# Processing Record | coahuayana
# Processing Record | namwala
# City not found | tunduru
# Processing Record | maniitsoq
# Processing Record | minnedosa
# Processing Record | havre-saint-pierre
# Processing Record | chizhou
# Processing Record | lekoni
# Processing Record | mildura
# Processing Record | yarmouth
# Processing Record | umm kaddadah
# Processing Record | atar
# Processing Record | tevaitoa
# Processing Record | pundaguitan
# Processing Record | ampanihy
# Processing Record | bawku
# Processing Record | ypsonas
# Processing Record | zalantun
# Processing Record | hailey

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dictionary of results
weather_data_dict = {
    "City": city_name,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": clouds,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
#Create dataframe from dictionary
weather_data = pd.DataFrame(weather_data_dict)
#Set index column name
weather_data.index.names = ['City_ID']
# Export dataframe to csv
file_path = os.path.join("output_data","cities.csv")
weather_data.to_csv(file_path)
# Display DataFrame
weather_data.head()
# Out:
#                     City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 Neiafu -18.65 -173.98     73.40        69          75
# 1                 Kupang -10.17  123.58     72.23        80          29
# 2                 Albany  42.60  -73.97     73.00        38           0
# 3        Arraial do Cabo -22.97  -42.03     84.20        65           0
# 4            East London -33.02   27.91     57.20        67           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.82      TO  1600109740
# 1              9.40      ID  1600109741
# 2              1.99      US  1600109665
# 3             16.11      BR  1600109741
# 4             11.41      ZA  1600109741

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  570.000000  570.000000  570.000000  570.000000  570.000000  570.000000
# mean    18.794228   19.023561   66.888982   69.147368   51.071930    7.913035
# std     33.175294   91.213028   15.983755   22.424003   39.936946    5.444219
# min    -54.800000 -179.170000   29.390000    1.000000    0.000000    0.220000
# 25%     -9.650000  -62.107500   53.382500   55.000000    5.000000    3.890000
# 50%     22.475000   25.385000   69.800000   74.000000   51.000000    6.710000
# 75%     47.825000  101.115000   78.800000   87.000000   91.000000   10.342500
# max     78.220000  179.320000  106.270000  100.000000  100.000000   32.210000
#
#                Date
# count  5.700000e+02
# mean   1.600110e+09
# std    8.173677e+01
# min    1.600109e+09
# 25%    1.600110e+09
# 50%    1.600110e+09
# 75%    1.600110e+09
# max    1.600110e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_gr_than_100 = weather_data[weather_data["Humidity"] > 100]
len(humidity_gr_than_100)
# Conclusion: skipping this step as there are no cities with humidity greater than 100%
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
output_path_fig1 = os.path.join("output_data","fig1.png")
plt.savefig(output_path_fig1)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
output_path_fig2 = os.path.join("output_data","fig2.png")
plt.savefig(output_path_fig2)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
output_path_fig3 = os.path.join("output_data","fig3.png")
plt.savefig(output_path_fig3)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
output_path_fig4 = os.path.join("output_data","fig4.png")
plt.savefig(output_path_fig4)

# %% [markdown]
# ## Linear Regression

# %%
# Split dataset into Hemispheres: Nothern = lat > 0, southern = lat < 0
northern_hemisphere = weather_data[weather_data["Lat"] > 0]
southern_hemisphere = weather_data[weather_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (7.5, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
# output plot to file
output_path_fig5 = os.path.join("output_data","fig5.png")
plt.savefig(output_path_fig5)
# Out:
# r = -0.8177655172655321

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 90), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig6 = os.path.join("output_data","fig6.png")
plt.savefig(output_path_fig6)
# Out:
# r = 0.7185333677266857

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_data = nothern_hemisphere["Lat"]
y_data = nothern_hemisphere["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (45, 15), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig7 = os.path.join("output_data","fig7.png")
plt.savefig(output_path_fig7)
# Out:
# r = 0.07719220387656148

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 10), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig8 = os.path.join("output_data","fig8.png")
plt.savefig(output_path_fig8)
# Out:
# r = 0.055770097171213937

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (7.5, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig9 = os.path.join("output_data","fig9.png")
plt.savefig(output_path_fig9)
# Out:
# r = 0.02007943168152642

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 50), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig10 = os.path.join("output_data","fig10.png")
plt.savefig(output_path_fig10)
# Out:
# r = 0.19748718864091827

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (30, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig11 = os.path.join("output_data","fig11.png")
plt.savefig(output_path_fig11)
# Out:
# r = 0.12187130642439145

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-50, 35), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig12 = os.path.join("output_data","fig12.png")
plt.savefig(output_path_fig12)
# Out:
# r = -0.2167955826105895
