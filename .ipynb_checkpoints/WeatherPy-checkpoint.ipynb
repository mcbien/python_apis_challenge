# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Links:
# python library: https://pypi.python.org/pypi/citipy
#
# Weather api: https://openweathermap.org/api

# %%
import random
from citipy import citipy
import requests
import json
from pprint import pprint
from api_keys import weather_api_key
import pandas as pd
import os
import matplotlib.pyplot as plt
import datetime
from scipy.stats import linregress

# %% [markdown]
# ## Generate Cities List

# %%
# Generate cities lists
cities = []

# Loop to create randon latitudes and longitudes
for i in range(0,1500):
    lat = round(random.uniform(-90,90),2)
    lng = round(random.uniform(-180,180),2)
    # Use citipy to find the nearest city to the (lat, lng)
    city = citipy.nearest_city(lat, lng)
    # Use citipy to return the name of the neareat city
    city_name = city.city_name
    # Append city name to city list
    cities.append(city_name)
# Remove any duplicates in the cities list
cities = list(dict.fromkeys(cities))
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build base URL for API call
weather_response = []
base_url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weather_api_key + "&units=imperial" + "&q="
counter = 0

#create lists empty lists to hold desired data
city_name = []
latitude = []
longitude = []
temp_max = []
humidity = []
clouds = []
wind_speed = []
date = []
country = []

# API call loop
for citi in cities:
    query_url = base_url + citi
    try:
        response = requests.get(query_url).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        temp_max.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        clouds.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record | {citi}")
    except:
        print(f"City not found | {citi}")
# Out:
# Processing Record | mataura
# Processing Record | tallahassee
# Processing Record | flinders
# Processing Record | chuy
# Processing Record | hithadhoo
# Processing Record | sabzevar
# Processing Record | lappeenranta
# Processing Record | upernavik
# Processing Record | birao
# Processing Record | laterza
# Processing Record | albany
# Processing Record | punta arenas
# Processing Record | arraial do cabo
# City not found | vaitupu
# Processing Record | vila
# City not found | sentyabrskiy
# Processing Record | padang
# City not found | taolanaro
# Processing Record | kapaa
# Processing Record | luxor
# Processing Record | port alfred
# Processing Record | castro
# Processing Record | yellowknife
# Processing Record | avarua
# City not found | umzimvubu
# Processing Record | lagoa
# Processing Record | atuona
# Processing Record | plouzane
# Processing Record | barrow
# Processing Record | portland
# Processing Record | port-gentil
# Processing Record | vaini
# Processing Record | bluff
# Processing Record | nemuro
# City not found | grand river south east
# City not found | attawapiskat
# Processing Record | georgetown
# Processing Record | busselton
# Processing Record | mogeiro
# Processing Record | auki
# Processing Record | airai
# Processing Record | severo-kurilsk
# Processing Record | jumla
# Processing Record | longyearbyen
# Processing Record | aranos
# Processing Record | bredasdorp
# Processing Record | novobirilyussy
# Processing Record | mandalgovi
# Processing Record | thinadhoo
# Processing Record | nome
# Processing Record | risor
# Processing Record | ribeira grande
# Processing Record | shetpe
# Processing Record | sitka
# Processing Record | bathsheba
# Processing Record | bethel
# Processing Record | dir
# Processing Record | cabo san lucas
# Processing Record | new norfolk
# Processing Record | tuktoyaktuk
# Processing Record | rikitea
# Processing Record | oranjestad
# Processing Record | sabang
# Processing Record | geraldton
# Processing Record | yatou
# Processing Record | thompson
# City not found | barentsburg
# Processing Record | penhold
# Processing Record | kathu
# City not found | piryion
# Processing Record | cape girardeau
# Processing Record | fort saint james
# Processing Record | kirovskiy
# Processing Record | provideniya
# Processing Record | emerald
# Processing Record | jamestown
# Processing Record | norman wells
# City not found | illoqqortoormiut
# Processing Record | suhbaatar
# Processing Record | tasiilaq
# Processing Record | jucuaran
# Processing Record | hilo
# Processing Record | tatvan
# Processing Record | mount gambier
# Processing Record | gizo
# Processing Record | san jose
# Processing Record | kungurtug
# Processing Record | lompoc
# Processing Record | tignere
# Processing Record | saskylakh
# Processing Record | saint george
# Processing Record | coquimbo
# Processing Record | butaritari
# Processing Record | tessalit
# Processing Record | mount isa
# Processing Record | srednekolymsk
# Processing Record | udachnyy
# Processing Record | puerto ayora
# Processing Record | tiksi
# Processing Record | saint-philippe
# Processing Record | tabou
# City not found | miranorte
# Processing Record | victoria
# Processing Record | port elizabeth
# Processing Record | rosario do sul
# Processing Record | nikolskoye
# Processing Record | olafsvik
# Processing Record | rundu
# Processing Record | salalah
# Processing Record | mongo
# Processing Record | cape town
# Processing Record | felanitx
# Processing Record | ushuaia
# Processing Record | baghdad
# Processing Record | grand gaube
# Processing Record | mozarlandia
# Processing Record | klaksvik
# Processing Record | la ronge
# Processing Record | clemson
# Processing Record | carnarvon
# Processing Record | east london
# Processing Record | hermanus
# Processing Record | iqaluit
# Processing Record | lebu
# City not found | nizhneyansk
# Processing Record | pskov
# Processing Record | kodiak
# Processing Record | baykit
# Processing Record | maymyo
# Processing Record | katherine
# Processing Record | kalmunai
# City not found | san jose de pane
# Processing Record | kangaatsiaq
# Processing Record | khatanga
# Processing Record | gamba
# Processing Record | beauchamps
# City not found | phan rang
# Processing Record | pakxan
# Processing Record | paamiut
# Processing Record | jeremie
# Processing Record | san fernando
# Processing Record | lata
# Processing Record | dunda
# City not found | babanusah
# Processing Record | kunming
# Processing Record | qaanaaq
# Processing Record | nishihara
# Processing Record | dingle
# Processing Record | nargana
# City not found | glubokoe
# Processing Record | faanui
# Processing Record | talnakh
# Processing Record | zaranj
# Processing Record | riyadh
# Processing Record | carutapera
# Processing Record | cherskiy
# Processing Record | gorontalo
# City not found | falealupo
# Processing Record | urumqi
# Processing Record | stutterheim
# Processing Record | guerrero negro
# Processing Record | port lincoln
# Processing Record | kaitangata
# Processing Record | san patricio
# Processing Record | ponta do sol
# City not found | ardistan
# Processing Record | dikson
# Processing Record | torbay
# Processing Record | taltal
# Processing Record | gat
# Processing Record | sakata
# Processing Record | summerville
# Processing Record | udaipura
# Processing Record | prince albert
# Processing Record | sungaipenuh
# Processing Record | miri
# Processing Record | palmer
# Processing Record | hasaki
# Processing Record | maragogi
# Processing Record | havre-saint-pierre
# Processing Record | bambanglipuro
# Processing Record | conde
# Processing Record | harper
# Processing Record | mahebourg
# Processing Record | oktyabrskiy
# Processing Record | dakar
# City not found | lucatan
# Processing Record | porto walter
# Processing Record | store heddinge
# Processing Record | mogadishu
# Processing Record | vila franca do campo
# Processing Record | shelburne
# Processing Record | hamirpur
# Processing Record | kudahuvadhoo
# Processing Record | ostrovnoy
# City not found | juifang
# Processing Record | raudeberg
# Processing Record | pandan
# Processing Record | verkhoyansk
# Processing Record | fairbanks
# City not found | samusu
# Processing Record | hunfeld
# Processing Record | garango
# City not found | skagastrond
# Processing Record | yar-sale
# Processing Record | husavik
# Processing Record | hobart
# Processing Record | ixtapa
# City not found | wulanhaote
# Processing Record | avera
# Processing Record | roald
# Processing Record | morki
# Processing Record | sinnamary
# Processing Record | midland
# Processing Record | puyang
# Processing Record | urusha
# Processing Record | ilulissat
# Processing Record | arman
# Processing Record | shimanovsk
# Processing Record | qitaihe
# Processing Record | kasangulu
# Processing Record | atambua
# Processing Record | abu kamal
# Processing Record | tura
# Processing Record | praia da vitoria
# Processing Record | sao joao da barra
# Processing Record | beloha
# Processing Record | vouliagmeni
# Processing Record | kaspiyskiy
# Processing Record | lucea
# Processing Record | marsh harbour
# Processing Record | ocean city
# Processing Record | barreirinhas
# City not found | belushya guba
# Processing Record | paita
# Processing Record | halifax
# Processing Record | tyrma
# Processing Record | la palma
# Processing Record | naze
# Processing Record | nahrin
# Processing Record | tuatapere
# Processing Record | clyde river
# Processing Record | valparaiso
# Processing Record | port blair
# Processing Record | camana
# Processing Record | victoria point
# Processing Record | iberia
# Processing Record | kostomuksha
# Processing Record | cape canaveral
# Processing Record | lixourion
# Processing Record | chokurdakh
# Processing Record | touros
# Processing Record | rafai
# Processing Record | taoudenni
# Processing Record | pacifica
# Processing Record | kahului
# Processing Record | north bend
# Processing Record | labuhan
# Processing Record | petropavlovsk-kamchatskiy
# Processing Record | alice
# Processing Record | haines junction
# Processing Record | marawi
# Processing Record | hambantota
# Processing Record | egvekinot
# Processing Record | roma
# Processing Record | chicama
# Processing Record | mantua
# Processing Record | agadir
# Processing Record | kimbe
# Processing Record | hovd
# Processing Record | rocha
# Processing Record | falciu
# Processing Record | marakkanam
# Processing Record | liverpool
# Processing Record | pyapon
# Processing Record | bira
# Processing Record | santa marinella
# Processing Record | komsomolets
# Processing Record | hofn
# Processing Record | esperance
# Processing Record | providencia
# Processing Record | opunake
# Processing Record | bongandanga
# Processing Record | umm kaddadah
# Processing Record | meulaboh
# Processing Record | okakarara
# Processing Record | saint-georges
# Processing Record | camacha
# Processing Record | pevek
# Processing Record | anadyr
# Processing Record | hualmay
# Processing Record | mugur-aksy
# Processing Record | comodoro rivadavia
# Processing Record | lasa
# Processing Record | santa helena
# City not found | tokzar
# Processing Record | rawson
# Processing Record | chake chake
# Processing Record | koungou
# Processing Record | kidal
# Processing Record | katsuura
# Processing Record | saint anthony
# Processing Record | isangel
# Processing Record | nouadhibou
# City not found | satitoa
# Processing Record | raduzhnyy
# Processing Record | mishkino
# Processing Record | tucumcari
# Processing Record | souillac
# Processing Record | sibolga
# Processing Record | rio grande
# Processing Record | novokizhinginsk
# Processing Record | hachinohe
# Processing Record | naryan-mar
# Processing Record | qaqortoq
# Processing Record | conceicao da barra
# Processing Record | mandera
# Processing Record | hobyo
# Processing Record | mariental
# Processing Record | westport
# Processing Record | boyuibe
# Processing Record | ishigaki
# Processing Record | dawei
# Processing Record | kumo
# Processing Record | mar del plata
# Processing Record | bara
# Processing Record | chapais
# Processing Record | manokwari
# Processing Record | glenwood springs
# Processing Record | cockburn town
# Processing Record | ordzhonikidze
# Processing Record | lantawan
# Processing Record | anzhero-sudzhensk
# Processing Record | bonfim
# Processing Record | belmonte
# City not found | viligili
# Processing Record | nuoro
# City not found | kalomo
# Processing Record | margate
# Processing Record | beringovskiy
# Processing Record | reconquista
# City not found | mutsamudu
# Processing Record | waiuku
# Processing Record | vardo
# Processing Record | grand-santi
# Processing Record | imbituba
# Processing Record | bambous virieux
# City not found | mys shmidta
# Processing Record | boende
# Processing Record | uvinza
# Processing Record | myitkyina
# Processing Record | beysehir
# Processing Record | ancud
# Processing Record | narsaq
# Processing Record | mahibadhoo
# Processing Record | batagay
# Processing Record | queanbeyan
# Processing Record | high level
# Processing Record | tazovskiy
# Processing Record | channel-port aux basques
# Processing Record | albanel
# Processing Record | anito
# Processing Record | santa ines
# Processing Record | coihueco
# City not found | barawe
# Processing Record | cayenne
# Processing Record | mahon
# Processing Record | lavrentiya
# Processing Record | pangnirtung
# Processing Record | ballina
# Processing Record | beba
# Processing Record | panjab
# City not found | tidore
# Processing Record | fonte boa
# City not found | saleaula
# Processing Record | tairua
# Processing Record | aykhal
# City not found | playia
# Processing Record | cidreira
# Processing Record | aklavik
# Processing Record | codrington
# Processing Record | jawhar
# Processing Record | la rioja
# Processing Record | bandarbeyla
# Processing Record | porto santo
# Processing Record | khani
# Processing Record | berlevag
# Processing Record | leningradskiy
# Processing Record | sampit
# Processing Record | big spring
# Processing Record | jalu
# Processing Record | shache
# Processing Record | kilindoni
# Processing Record | udalguri
# Processing Record | dauphin
# Processing Record | hirara
# Processing Record | ozernovskiy
# City not found | ruatoria
# Processing Record | luderitz
# Processing Record | kapit
# Processing Record | shakawe
# Processing Record | te anau
# Processing Record | ningxiang
# Processing Record | tiverton
# Processing Record | mwense
# Processing Record | gigmoto
# Processing Record | kyren
# City not found | sungai siput utara
# Processing Record | fuyu
# Processing Record | nyurba
# Processing Record | maniitsoq
# Processing Record | alofi
# Processing Record | young
# Processing Record | strezhevoy
# City not found | candawaga
# City not found | tabiauea
# Processing Record | lodja
# Processing Record | alamor
# Processing Record | kenai
# Processing Record | tanete
# Processing Record | bilgoraj
# Processing Record | lillooet
# Processing Record | vostok
# Processing Record | bengkulu
# Processing Record | garachine
# Processing Record | bemidji
# Processing Record | fomboni
# Processing Record | jalingo
# Processing Record | tonantins
# Processing Record | urengoy
# City not found | artyk
# Processing Record | teguldet
# Processing Record | antofagasta
# Processing Record | zverinogolovskoye
# City not found | bolsheustikinskoye
# Processing Record | broome
# Processing Record | dandong
# Processing Record | hongjiang
# Processing Record | vao
# Processing Record | sao felix do xingu
# Processing Record | ahipara
# City not found | amderma
# Processing Record | okato
# Processing Record | berdigestyakh
# Processing Record | jyvaskyla
# Processing Record | bethanien
# City not found | lalmanir hat
# Processing Record | biak
# Processing Record | hamilton
# Processing Record | noumea
# Processing Record | canoa
# Processing Record | broken hill
# Processing Record | crotone
# Processing Record | mlowo
# Processing Record | guiratinga
# Processing Record | tete
# Processing Record | ritchie
# City not found | achisay
# Processing Record | los alamos
# Processing Record | panguna
# Processing Record | lithakia
# Processing Record | aksarka
# Processing Record | rudnogorsk
# Processing Record | port macquarie
# Processing Record | kismayo
# Processing Record | bonavista
# Processing Record | guymon
# Processing Record | caravelas
# Processing Record | port shepstone
# Processing Record | abu samrah
# Processing Record | kailua
# Processing Record | izhma
# Processing Record | porto novo
# Processing Record | san quintin
# Processing Record | placido de castro
# Processing Record | uyar
# Processing Record | mecca
# Processing Record | bilibino
# Processing Record | limbang
# Processing Record | namibe
# Processing Record | oussouye
# Processing Record | santa isabel do rio negro
# Processing Record | mayumba
# City not found | penjamillo
# Processing Record | muscat
# Processing Record | benghazi
# Processing Record | kruisfontein
# Processing Record | antalaha
# Processing Record | mezen
# Processing Record | sri aman
# Processing Record | tolaga bay
# Processing Record | razole
# City not found | lolua
# Processing Record | kyshtovka
# Processing Record | vaitape
# Processing Record | waipawa
# Processing Record | abnub
# Processing Record | eucaliptus
# Processing Record | harindanga
# Processing Record | buala
# Processing Record | berbera
# City not found | matameye
# Processing Record | vanimo
# Processing Record | thanh hoa
# Processing Record | kawalu
# Processing Record | aripuana
# Processing Record | nuuk
# Processing Record | veraval
# City not found | meyungs
# Processing Record | muros
# Processing Record | guane
# Processing Record | mackay
# Processing Record | lichuan
# Processing Record | yulara
# Processing Record | temyasovo
# Processing Record | tombouctou
# Processing Record | kingaroy
# Processing Record | fare
# Processing Record | namatanai
# Processing Record | dejen
# Processing Record | nanortalik
# City not found | samatau
# Processing Record | college
# Processing Record | kulhudhuffushi
# Processing Record | honningsvag
# Processing Record | olinda
# City not found | tarudant
# Processing Record | tiarei
# Processing Record | polyarnyy
# Processing Record | gushikawa
# Processing Record | la macarena
# Processing Record | muroto
# Processing Record | wamba
# Processing Record | kavieng
# Processing Record | tual
# Processing Record | aras
# Processing Record | bonthe
# Processing Record | ha giang
# Processing Record | gobabis
# Processing Record | macon
# Processing Record | ambulu
# Processing Record | sorrento
# Processing Record | cooma
# Processing Record | barcelona
# Processing Record | tolmachevo
# Processing Record | san lawrenz
# City not found | louisbourg
# Processing Record | ariquemes
# Processing Record | mandiana
# Processing Record | tulsipur
# Processing Record | sioux lookout
# Processing Record | vilyuysk
# Processing Record | brownsville
# Processing Record | oistins
# Processing Record | saint-joseph
# Processing Record | lastoursville
# Processing Record | weiser
# Processing Record | guilin
# Processing Record | chute-aux-outardes
# Processing Record | nicoya
# City not found | boatlaname
# City not found | palabuhanratu
# Processing Record | troy
# Processing Record | horodok
# City not found | anar darreh
# Processing Record | nebolchi
# Processing Record | kardymovo
# Processing Record | aksu
# Processing Record | chimore
# Processing Record | flers
# Processing Record | alekseyevka
# Processing Record | qazigund
# Processing Record | fortuna
# Processing Record | pudukkottai
# Processing Record | urucara
# Processing Record | nyagan
# City not found | skalistyy
# Processing Record | nhulunbuy
# Processing Record | lorengau
# Processing Record | bud
# Processing Record | susanville
# Processing Record | pierre
# Processing Record | bell ville
# Processing Record | andenes
# Processing Record | camiri
# Processing Record | quelimane
# Processing Record | pauini
# Processing Record | sidney

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dictionary of results
weather_data_dict = {
    "City": city_name,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": clouds,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
#Create dataframe from dictionary
weather_data = pd.DataFrame(weather_data_dict)
#Set index column name
weather_data.index.names = ['City_ID']
# Export dataframe to csv
file_path = os.path.join("output_data","cities.csv")
weather_data.to_csv(file_path)
# Display DataFrame
weather_data.head()
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            Mataura -46.19  168.86     39.99        80          32
# 1        Tallahassee  30.44  -84.28     78.80        78          90
# 2           Flinders -34.58  150.86     57.99        84         100
# 3               Chui -33.70  -53.46     68.13        58           3
# 4          Hithadhoo  -0.60   73.08     82.67        78          73
#
#          Wind Speed Country        Date
# City_ID
# 0             11.01      NZ  1600366190
# 1             12.75      US  1600366023
# 2              1.01      AU  1600366193
# 3              7.43      UY  1600366195
# 4             11.18      MV  1600366195

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  535.000000  535.000000  535.000000  535.000000  535.000000  535.000000
# mean    19.596187   19.214561   67.540206   69.297196   48.248598    8.432299
# std     33.294216   91.571422   16.615107   21.022181   37.384177    6.123063
# min    -54.800000 -179.170000   20.950000   11.000000    0.000000    0.290000
# 25%     -7.340000  -62.865000   53.600000   58.000000    9.000000    3.980000
# 50%     22.680000   22.720000   71.040000   75.000000   42.000000    6.930000
# 75%     47.840000   99.560000   79.855000   85.000000   85.000000   11.410000
# max     78.220000  179.320000  105.400000  100.000000  100.000000   43.730000
#
#                Date
# count  5.350000e+02
# mean   1.600366e+09
# std    1.968965e+02
# min    1.600366e+09
# 25%    1.600366e+09
# 50%    1.600366e+09
# 75%    1.600367e+09
# max    1.600367e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_gr_than_100 = weather_data[weather_data["Humidity"] > 100]
len(humidity_gr_than_100)
# Conclusion: skipping this step as there are no cities with humidity greater than 100%
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
output_path_fig1 = os.path.join("output_data","fig1.png")
plt.savefig(output_path_fig1)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
output_path_fig2 = os.path.join("output_data","fig2.png")
plt.savefig(output_path_fig2)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
output_path_fig3 = os.path.join("output_data","fig3.png")
plt.savefig(output_path_fig3)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
output_path_fig4 = os.path.join("output_data","fig4.png")
plt.savefig(output_path_fig4)

# %% [markdown]
# ## Linear Regression

# %%
# Split dataset into Hemispheres: Nothern = lat > 0, southern = lat < 0
northern_hemisphere = weather_data[weather_data["Lat"] > 0]
southern_hemisphere = weather_data[weather_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (7.5, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
# output plot to file
output_path_fig5 = os.path.join("output_data","fig5.png")
plt.savefig(output_path_fig5)
# Out:
# r = -0.8282247988289985

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 90), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig6 = os.path.join("output_data","fig6.png")
plt.savefig(output_path_fig6)
# Out:
# r = 0.7615123505538618

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (45, 15), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig7 = os.path.join("output_data","fig7.png")
plt.savefig(output_path_fig7)
# Out:
# r = 0.06698896260716765

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 10), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig8 = os.path.join("output_data","fig8.png")
plt.savefig(output_path_fig8)
# Out:
# r = -0.05442948589698842

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (7.5, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig9 = os.path.join("output_data","fig9.png")
plt.savefig(output_path_fig9)
# Out:
# r = 0.05483828221598141

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 50), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig10 = os.path.join("output_data","fig10.png")
plt.savefig(output_path_fig10)
# Out:
# r = 0.17740035857454836

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (30, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig11 = os.path.join("output_data","fig11.png")
plt.savefig(output_path_fig11)
# Out:
# r = 0.050970078417405335

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-50, 35), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig12 = os.path.join("output_data","fig12.png")
plt.savefig(output_path_fig12)
# Out:
# r = -0.2875624873063094
