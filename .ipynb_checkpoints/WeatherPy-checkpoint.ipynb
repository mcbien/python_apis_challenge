# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Links:
# python library: https://pypi.python.org/pypi/citipy
#
# Weather api: https://openweathermap.org/api

# %%
import random
from citipy import citipy
import requests
import json
from pprint import pprint
from api_keys import weather_api_key
import pandas as pd
import os
import matplotlib.pyplot as plt
import datetime
from scipy.stats import linregress

# %% [markdown]
# ## Generate Cities List

# %%
# Generate cities lists
cities = []

# Loop to create randon latitudes and longitudes
for i in range(0,1500):
    lat = round(random.uniform(-90,90),2)
    lng = round(random.uniform(-180,180),2)
    # Use citipy to find the nearest city to the (lat, lng)
    city = citipy.nearest_city(lat, lng)
    # Use citipy to return the name of the neareat city
    city_name = city.city_name
    # Append city name to city list
    cities.append(city_name)
# Remove any duplicates in the cities list
cities = list(dict.fromkeys(cities))
len(cities)
# Out:
# 634

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build base URL for API call
weather_response = []
base_url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weather_api_key + "&units=imperial" + "&q="
counter = 0

#create lists empty lists to hold desired data
city_name = []
latitude = []
longitude = []
temp_max = []
humidity = []
clouds = []
wind_speed = []
date = []
country = []

# API call loop
for citi in cities:
    query_url = base_url + citi
    try:
        response = requests.get(query_url).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        temp_max.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        clouds.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record | {citi}")
    except:
        print(f"City not found | {citi}")
# Out:
# Processing Record | ahipara
# Processing Record | acapulco
# Processing Record | chokurdakh
# Processing Record | atuona
# Processing Record | progreso
# Processing Record | yellowknife
# Processing Record | mataura
# City not found | barentsburg
# Processing Record | aktyubinskiy
# Processing Record | tuktoyaktuk
# Processing Record | baculin
# Processing Record | iqaluit
# Processing Record | upernavik
# Processing Record | vardo
# Processing Record | cayce
# Processing Record | katsuura
# Processing Record | dayong
# Processing Record | rikitea
# Processing Record | sola
# Processing Record | bredasdorp
# Processing Record | rawson
# Processing Record | port alfred
# City not found | bolungarvik
# Processing Record | ushuaia
# Processing Record | oktyabrskiy
# Processing Record | usinsk
# Processing Record | pleshanovo
# Processing Record | henties bay
# Processing Record | punta arenas
# Processing Record | dikson
# Processing Record | geraldton
# Processing Record | havre-saint-pierre
# Processing Record | bathsheba
# Processing Record | jamestown
# Processing Record | vao
# Processing Record | kalengwa
# Processing Record | mar del plata
# Processing Record | dingle
# Processing Record | nikolskoye
# City not found | teneguiban
# Processing Record | salinopolis
# Processing Record | birao
# Processing Record | jacareacanga
# Processing Record | faanui
# Processing Record | pisco
# Processing Record | touros
# City not found | urdzhar
# Processing Record | muscatine
# Processing Record | den helder
# Processing Record | saint george
# Processing Record | tiksi
# Processing Record | busselton
# Processing Record | lagoa
# Processing Record | khatanga
# Processing Record | bethel
# Processing Record | codrington
# Processing Record | emerald
# Processing Record | ilulissat
# Processing Record | kavieng
# City not found | illoqqortoormiut
# Processing Record | kapaa
# Processing Record | jumla
# Processing Record | hilo
# Processing Record | barrow
# Processing Record | avarua
# Processing Record | castro
# City not found | mergui
# Processing Record | camacha
# Processing Record | vila franca do campo
# City not found | amderma
# Processing Record | fairbanks
# Processing Record | cairns
# Processing Record | orje
# Processing Record | akyab
# Processing Record | rorvik
# Processing Record | vega de alatorre
# Processing Record | silveira
# Processing Record | bandarbeyla
# Processing Record | bilibino
# Processing Record | lahat
# Processing Record | hornepayne
# Processing Record | great yarmouth
# Processing Record | caravelas
# Processing Record | mount isa
# Processing Record | tiznit
# Processing Record | sorland
# Processing Record | vallenar
# Processing Record | bjornevatn
# Processing Record | zhangye
# Processing Record | puerto ayora
# Processing Record | provideniya
# Processing Record | east london
# Processing Record | albany
# Processing Record | clyde river
# City not found | karamea
# Processing Record | hithadhoo
# Processing Record | carnarvon
# Processing Record | miri
# Processing Record | cervo
# Processing Record | atar
# Processing Record | rock springs
# Processing Record | san patricio
# Processing Record | eslamshahr
# Processing Record | souillac
# Processing Record | cravo norte
# Processing Record | butaritari
# Processing Record | esperance
# Processing Record | raudeberg
# Processing Record | bengkulu
# City not found | mentok
# Processing Record | shelburne
# Processing Record | saint-philippe
# Processing Record | ilebo
# Processing Record | bambous virieux
# Processing Record | piacabucu
# Processing Record | heidenau
# Processing Record | arraial do cabo
# Processing Record | kieta
# Processing Record | torbay
# City not found | sentyabrskiy
# Processing Record | hirara
# Processing Record | namatanai
# Processing Record | sao filipe
# Processing Record | kassala
# Processing Record | narsaq
# Processing Record | westport
# Processing Record | petershagen
# Processing Record | taywarah
# Processing Record | kodiak
# Processing Record | moyale
# Processing Record | arkhangelskoye
# Processing Record | havelock
# Processing Record | kloulklubed
# Processing Record | malakal
# Processing Record | logansport
# Processing Record | bolshoy lug
# Processing Record | postojna
# Processing Record | padang
# City not found | kadykchan
# Processing Record | kenai
# Processing Record | kapit
# Processing Record | salalah
# Processing Record | okhotsk
# Processing Record | zaysan
# City not found | tabiauea
# Processing Record | ribeira grande
# Processing Record | basco
# Processing Record | gander
# Processing Record | corner brook
# Processing Record | hermanus
# Processing Record | lensk
# Processing Record | hasaki
# Processing Record | sangar
# Processing Record | bluff
# City not found | satitoa
# City not found | aflu
# Processing Record | cockburn town
# Processing Record | severo-yeniseyskiy
# Processing Record | qaanaaq
# Processing Record | port elizabeth
# Processing Record | norman wells
# Processing Record | shimoda
# Processing Record | ulenje
# Processing Record | rajaldesar
# Processing Record | jiamusi
# Processing Record | new norfolk
# Processing Record | chapais
# Processing Record | kafanchan
# Processing Record | aswan
# City not found | mys shmidta
# Processing Record | dakar
# Processing Record | bud
# Processing Record | yima
# Processing Record | balakhta
# Processing Record | gualan
# Processing Record | pevek
# City not found | taolanaro
# Processing Record | gao
# Processing Record | batagay-alyta
# Processing Record | luderitz
# Processing Record | saldanha
# Processing Record | dunedin
# Processing Record | cape town
# Processing Record | yerbogachen
# Processing Record | todos santos
# Processing Record | flin flon
# Processing Record | sesheke
# Processing Record | alice springs
# Processing Record | miracema do tocantins
# Processing Record | dawei
# Processing Record | aitape
# Processing Record | podor
# Processing Record | nenjiang
# Processing Record | groningen
# Processing Record | port blair
# Processing Record | mitha tiwana
# Processing Record | khorixas
# Processing Record | ambulu
# Processing Record | guozhen
# Processing Record | saskylakh
# Processing Record | mitu
# Processing Record | grand gaube
# Processing Record | guangyuan
# Processing Record | bambanglipuro
# City not found | ijaki
# Processing Record | batamshinskiy
# Processing Record | te anau
# Processing Record | hammerfest
# Processing Record | tuy hoa
# Processing Record | buenos aires
# Processing Record | mount gambier
# Processing Record | cherskiy
# City not found | samusu
# Processing Record | anadyr
# Processing Record | barra do corda
# Processing Record | natal
# Processing Record | keti bandar
# Processing Record | abha
# Processing Record | hobart
# City not found | tsihombe
# Processing Record | road town
# Processing Record | vaini
# Processing Record | nabire
# Processing Record | huarmey
# Processing Record | yokadouma
# Processing Record | bourail
# Processing Record | udachnyy
# Processing Record | nanortalik
# City not found | grand river south east
# Processing Record | camana
# Processing Record | san javier
# City not found | marcona
# Processing Record | zabol
# Processing Record | zhigansk
# City not found | ruatoria
# Processing Record | tikrit
# Processing Record | longyearbyen
# Processing Record | kaitangata
# City not found | juifang
# Processing Record | necochea
# Processing Record | marzuq
# Processing Record | trzebiatow
# Processing Record | leningradskiy
# Processing Record | vieux-habitants
# City not found | tumannyy
# Processing Record | tuatapere
# Processing Record | victoria
# Processing Record | haines junction
# Processing Record | verkhoyansk
# City not found | kracheh
# Processing Record | nyurba
# Processing Record | waverly
# Processing Record | coihaique
# Processing Record | vinces
# Processing Record | hovd
# Processing Record | muravlenko
# Processing Record | mahebourg
# Processing Record | antofagasta
# Processing Record | port hope
# City not found | litoral del san juan
# Processing Record | buritis
# Processing Record | cidreira
# Processing Record | lompoc
# Processing Record | xining
# Processing Record | la ronge
# Processing Record | kita
# City not found | lolua
# Processing Record | pemangkat
# Processing Record | sitka
# Processing Record | ukiah
# Processing Record | hamilton
# Processing Record | northam
# Processing Record | aykhal
# Processing Record | takapau
# Processing Record | fortuna
# Processing Record | constitucion
# Processing Record | beringovskiy
# Processing Record | mutis
# Processing Record | yar-sale
# Processing Record | majene
# Processing Record | tripoli
# Processing Record | hohhot
# Processing Record | kalabo
# Processing Record | churapcha
# Processing Record | tateyama
# Processing Record | la rioja
# Processing Record | gorgan
# Processing Record | oranjemund
# City not found | kamenskoye
# Processing Record | thompson
# Processing Record | svetlaya
# Processing Record | tasiilaq
# City not found | kuche
# Processing Record | aripuana
# Processing Record | graaff-reinet
# Processing Record | nsanje
# Processing Record | port lincoln
# Processing Record | plaridel
# Processing Record | vostok
# Processing Record | san vicente
# Processing Record | kashary
# Processing Record | kahului
# Processing Record | kruisfontein
# Processing Record | straumen
# Processing Record | karratha
# Processing Record | playa vicente
# Processing Record | hofn
# Processing Record | hobyo
# Processing Record | varna
# Processing Record | moss vale
# Processing Record | cabo san lucas
# Processing Record | abu kamal
# Processing Record | georgetown
# Processing Record | ouallam
# Processing Record | chokwe
# Processing Record | baisha
# Processing Record | husavik
# Processing Record | ankang
# Processing Record | sao joao da barra
# City not found | palabuhanratu
# Processing Record | simbahan
# City not found | angra
# City not found | bargal
# Processing Record | teya
# Processing Record | banda aceh
# Processing Record | osoyoos
# Processing Record | mutata
# Processing Record | lisakovsk
# Processing Record | coro
# Processing Record | orguz
# Processing Record | mercedes
# Processing Record | jardim
# Processing Record | las choapas
# Processing Record | lovington
# Processing Record | kholodnyy
# Processing Record | gainesville
# Processing Record | darhan
# Processing Record | mayo
# City not found | nizhneyansk
# Processing Record | henderson
# Processing Record | ancud
# Processing Record | methoni
# Processing Record | lere
# Processing Record | solnechnyy
# Processing Record | sulangan
# Processing Record | lorengau
# Processing Record | lima
# Processing Record | goldsboro
# Processing Record | ulladulla
# Processing Record | krasnoselkup
# Processing Record | terrace
# Processing Record | umm kaddadah
# City not found | ahumada
# Processing Record | sur
# Processing Record | san lawrenz
# Processing Record | ribeirao branco
# Processing Record | praya
# Processing Record | noumea
# Processing Record | port hardy
# Processing Record | tura
# City not found | vaitupu
# Processing Record | benton
# Processing Record | ponta do sol
# Processing Record | jizan
# Processing Record | kolomna
# City not found | cheuskiny
# Processing Record | mana
# Processing Record | lebu
# Processing Record | madimba
# Processing Record | matara
# Processing Record | singaraja
# City not found | usila
# Processing Record | haradok
# Processing Record | presidente dutra
# Processing Record | chimbote
# Processing Record | srednekolymsk
# Processing Record | yaguajay
# Processing Record | minab
# Processing Record | sinnamary
# Processing Record | bushehr
# Processing Record | balabac
# Processing Record | irbil
# Processing Record | samana
# Processing Record | high level
# Processing Record | severo-kurilsk
# Processing Record | ust-tarka
# Processing Record | vadso
# Processing Record | indian head
# Processing Record | maputo
# Processing Record | buta
# Processing Record | klaksvik
# City not found | umzimvubu
# Processing Record | pangai
# Processing Record | save
# Processing Record | avera
# Processing Record | japura
# Processing Record | svetlyy
# Processing Record | alta floresta
# Processing Record | ornskoldsvik
# Processing Record | juneau
# Processing Record | lufilufi
# Processing Record | san quintin
# City not found | meyungs
# Processing Record | galesong
# Processing Record | sisimiut
# Processing Record | korla
# City not found | felidhoo
# Processing Record | san andres
# Processing Record | agadir
# Processing Record | kovdor
# Processing Record | krasnokamensk
# Processing Record | santo tomas
# Processing Record | charters towers
# Processing Record | los llanos de aridane
# Processing Record | pingliang
# Processing Record | birjand
# Processing Record | sebring
# Processing Record | jiutai
# Processing Record | maniitsoq
# City not found | sorvag
# Processing Record | nome
# Processing Record | toledo
# Processing Record | san cristobal
# Processing Record | sandakan
# Processing Record | acarau
# Processing Record | kribi
# Processing Record | tezu
# Processing Record | shenkursk
# Processing Record | oksfjord
# Processing Record | guilin
# Processing Record | saint-augustin
# Processing Record | naze
# Processing Record | sorong
# Processing Record | chumikan
# Processing Record | goba
# Processing Record | aksarka
# Processing Record | sinegorye
# Processing Record | nacala
# Processing Record | zhezkazgan
# Processing Record | belyy yar
# Processing Record | mehamn
# Processing Record | sioux lookout
# Processing Record | blagoyevo
# Processing Record | nemuro
# Processing Record | ygatimi
# Processing Record | sidney
# Processing Record | talnakh
# Processing Record | wagga wagga
# Processing Record | hvolsvollur
# Processing Record | challans
# City not found | toliary
# Processing Record | havoysund
# Processing Record | honiara
# Processing Record | aklavik
# Processing Record | vestmannaeyjar
# Processing Record | jarvakandi
# Processing Record | petropavlovsk-kamchatskiy
# Processing Record | airai
# Processing Record | mendoza
# Processing Record | el alto
# Processing Record | jimenez
# Processing Record | kushiro
# Processing Record | vrede
# City not found | katha
# Processing Record | ostrovnoy
# Processing Record | celestun
# Processing Record | ternate
# Processing Record | mahibadhoo
# Processing Record | winchester
# Processing Record | puerto escondido
# Processing Record | fairhope
# Processing Record | kashi
# Processing Record | bex
# Processing Record | guerrero negro
# Processing Record | san martin
# Processing Record | puksoozero
# Processing Record | saint anthony
# Processing Record | port hawkesbury
# Processing Record | monze
# Processing Record | buraydah
# Processing Record | ende
# Processing Record | shubarshi
# Processing Record | koslan
# Processing Record | san francisco
# Processing Record | copiapo
# Processing Record | tome
# Processing Record | puerto ayacucho
# Processing Record | brigantine
# Processing Record | samarai
# Processing Record | bereda
# Processing Record | yulara
# Processing Record | morros
# Processing Record | pangnirtung
# Processing Record | kavaratti
# Processing Record | port moresby
# Processing Record | roma
# Processing Record | cabedelo
# Processing Record | bentiu
# Processing Record | qasigiannguit
# Processing Record | lagunas
# Processing Record | coahuayana
# City not found | macaboboni
# Processing Record | buckeye
# Processing Record | valparaiso
# Processing Record | ratnapura
# Processing Record | miles city
# Processing Record | nishihara
# Processing Record | pombia
# Processing Record | nadym
# Processing Record | lasa
# City not found | solovetskiy
# Processing Record | espinosa
# Processing Record | kilindoni
# Processing Record | luanda
# Processing Record | kamien pomorski
# Processing Record | mackay
# Processing Record | boa vista
# Processing Record | servia
# Processing Record | genhe
# Processing Record | teonthar
# Processing Record | kulhudhuffushi
# Processing Record | ampanihy
# Processing Record | yambio
# Processing Record | simao
# City not found | gorno-chuyskiy
# Processing Record | makakilo city
# Processing Record | reconquista
# Processing Record | namibe
# Processing Record | lavrentiya
# City not found | bokspits
# City not found | belushya guba
# Processing Record | sabang
# Processing Record | poum
# Processing Record | san jose
# Processing Record | makasar
# Processing Record | komsomolskiy
# Processing Record | ambovombe
# Processing Record | aalen
# Processing Record | uchana
# Processing Record | hami
# Processing Record | fort nelson
# Processing Record | ugoofaaru
# Processing Record | vila velha
# Processing Record | ondjiva
# Processing Record | belmonte
# Processing Record | porto walter
# Processing Record | melito di porto salvo
# Processing Record | koster
# City not found | andarab
# Processing Record | bereznik
# Processing Record | lesnoy
# Processing Record | viedma
# Processing Record | londoko
# Processing Record | banjar
# Processing Record | soignies
# Processing Record | senno
# City not found | wahran
# Processing Record | karasjok
# Processing Record | bonthe
# Processing Record | mutoko
# Processing Record | hervey bay
# Processing Record | nizwa
# Processing Record | privolnyy
# Processing Record | le pradet
# Processing Record | fasa
# Processing Record | onega
# Processing Record | derzhavinsk
# Processing Record | vanimo
# Processing Record | ajaccio
# Processing Record | athens
# Processing Record | zyryanka
# Processing Record | barmer
# Processing Record | woodward
# Processing Record | buchanan
# Processing Record | roald
# City not found | karkaralinsk
# Processing Record | ixtapa
# Processing Record | batagay
# Processing Record | ola
# Processing Record | yalutorovsk
# Processing Record | penzance
# Processing Record | vestmanna
# Processing Record | el mante
# Processing Record | green river
# Processing Record | bundaberg
# Processing Record | cerkezkoy
# City not found | hunza
# Processing Record | coquimbo
# Processing Record | grindavik
# Processing Record | beyneu
# Processing Record | comodoro rivadavia
# Processing Record | turba
# Processing Record | kungurtug
# Processing Record | prince rupert
# Processing Record | puga
# Processing Record | howard springs
# Processing Record | the valley
# Processing Record | eltham
# Processing Record | lillehammer
# Processing Record | eureka
# Processing Record | rauma
# City not found | cockburn harbour
# Processing Record | harper
# Processing Record | arlit
# Processing Record | goderich
# Processing Record | pangody
# Processing Record | valmiera
# City not found | attawapiskat
# Processing Record | baykit
# City not found | guelengdeng
# Processing Record | broken hill
# Processing Record | taltal
# Processing Record | luangwa
# Processing Record | palu
# Processing Record | atbasar
# Processing Record | la orilla
# Processing Record | launceston
# Processing Record | pokhara
# Processing Record | meulaboh
# Processing Record | dukat
# Processing Record | burnie
# Processing Record | tsaritsani
# City not found | toftir
# Processing Record | kutum
# Processing Record | conceicao do araguaia
# Processing Record | marawi
# Processing Record | mogadishu
# Processing Record | luan
# Processing Record | shunyi
# Processing Record | vuktyl
# Processing Record | ituiutaba
# Processing Record | alofi
# City not found | ondorhaan
# Processing Record | puerto madryn

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dictionary of results
weather_data_dict = {
    "City": city_name,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": clouds,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
#Create dataframe from dictionary
weather_data = pd.DataFrame(weather_data_dict)
#Set index column name
weather_data.index.names = ['City_ID']
# Export dataframe to csv
file_path = os.path.join("output_data","cities.csv")
weather_data.to_csv(file_path)
# Display DataFrame
weather_data.head()
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   Ahipara -35.17  173.17     56.28        83          51
# 1        Acapulco de Juárez  16.86  -99.89     82.40        78          75
# 2                Chokurdakh  70.63  147.92     41.79        86          25
# 3                    Atuona  -9.80 -139.03     77.25        78           5
# 4                  Progreso  21.28  -89.67     91.99        70          40
#
#          Wind Speed Country        Date
# City_ID
# 0             13.53      NZ  1600100105
# 1              4.70      MX  1600100105
# 2              6.87      RU  1600100107
# 3             16.87      PF  1600100108
# 4              8.05      MX  1600100109

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  577.000000  577.000000  577.000000  577.000000  577.000000  577.000000
# mean    21.290936   19.676464   67.672461   67.287695   46.925477    8.053536
# std     34.016634   90.561668   16.938279   22.756342   37.467435    5.549641
# min    -54.800000 -175.200000   28.400000    1.000000    0.000000    0.110000
# 25%     -7.950000  -61.350000   53.010000   54.000000    6.000000    3.940000
# 50%     25.520000   24.300000   69.800000   73.000000   40.000000    6.930000
# 75%     50.600000  101.770000   81.000000   85.000000   85.000000   10.690000
# max     78.220000  179.320000  109.870000  100.000000  100.000000   40.260000
#
#                Date
# count  5.770000e+02
# mean   1.600100e+09
# std    8.441302e+01
# min    1.600100e+09
# 25%    1.600100e+09
# 50%    1.600100e+09
# 75%    1.600100e+09
# max    1.600100e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_gr_than_100 = weather_data[weather_data["Humidity"] > 100]
len(humidity_gr_than_100)
# Conclusion: skipping this step as there are no cities with humidity greater than 100%
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
output_path_fig1 = os.path.join("output_data","fig1.png")
plt.savefig(output_path_fig1)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
output_path_fig2 = os.path.join("output_data","fig2.png")
plt.savefig(output_path_fig2)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
output_path_fig3 = os.path.join("output_data","fig3.png")
plt.savefig(output_path_fig3)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_data = weather_data["Lat"]
y_data = weather_data["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"City Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
output_path_fig4 = os.path.join("output_data","fig4.png")
plt.savefig(output_path_fig4)

# %% [markdown]
# ## Linear Regression

# %%
# Split dataset into Hemispheres: Nothern = lat > 0, southern = lat < 0
northern_hemisphere = weather_data[weather_data["Lat"] > 0]
southern_hemisphere = weather_data[weather_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (7.5, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
# output plot to file
output_path_fig5 = os.path.join("output_data","fig5.png")
plt.savefig(output_path_fig5)
# Out:
# r = -0.7943745491004375

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Max Temp"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Maximum Temperature ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 90), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig6 = os.path.join("output_data","fig6.png")
plt.savefig(output_path_fig6)
# Out:
# r = 0.7434598308613773

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_data = nothern_hemisphere["Lat"]
y_data = nothern_hemisphere["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (45, 15), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig7 = os.path.join("output_data","fig7.png")
plt.savefig(output_path_fig7)
# Out:
# r = 0.07719220387656148

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Humidity"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Humidity ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 10), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig8 = os.path.join("output_data","fig8.png")
plt.savefig(output_path_fig8)
# Out:
# r = 0.011260938258198065

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (7.5, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig9 = os.path.join("output_data","fig9.png")
plt.savefig(output_path_fig9)
# Out:
# r = 0.03012996666692599

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Cloudiness"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Cloudiness ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-55, 50), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig10 = os.path.join("output_data","fig10.png")
plt.savefig(output_path_fig10)
# Out:
# r = 0.17681607541098102

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_data = northern_hemisphere["Lat"]
y_data = northern_hemisphere["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Northern Hemisphere: Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (30, 30), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig11 = os.path.join("output_data","fig11.png")
plt.savefig(output_path_fig11)
# Out:
# r = 0.035669971694058604

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_data = southern_hemisphere["Lat"]
y_data = southern_hemisphere["Wind Speed"]
plt.scatter(x=x_data, y=y_data, marker="o",facecolors="lightblue",edgecolors="darkblue")
today = pd.to_datetime('today')
plt.title(f"Southern Hemisphere: Latitude vs. Wind Speed ({today.month}/{today.day}/{today.year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(x_data, y_data)
# Calculate the predictions for each value of x (# Rooms)
regression_values = x_data * slope + intercept
# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_data, regression_values, "red")
# add line equation to plot
plt.annotate(line_eq, (-50, 35), fontsize=15, color="red")
# add pearson's r value to plot 
print(f"r = {rvalue}")
output_path_fig12 = os.path.join("output_data","fig12.png")
plt.savefig(output_path_fig12)
# Out:
# r = -0.22359613609092185
