# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
file_path = os.path.join("output_data", "cities.csv")
weather_data = pd.read_csv(file_path)
weather_data.set_index(["City_ID"], inplace=True)
weather_data.head()
# Out:
#                     City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 Neiafu -18.65 -173.98     73.40        69          75
# 1                 Kupang -10.17  123.58     72.23        80          29
# 2                 Albany  42.60  -73.97     73.00        38           0
# 3        Arraial do Cabo -22.97  -42.03     84.20        65           0
# 4            East London -33.02   27.91     57.20        67           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.82      TO  1600109740
# 1              9.40      ID  1600109741
# 2              1.99      US  1600109665
# 3             16.11      BR  1600109741
# 4             11.41      ZA  1600109741

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
print(g_key)
# Out:
# AIzaSyCSel_7zt8qso61wDuTA0oEsW4lgA_9BpI

# %%
# access maps with unique API key
gmaps.configure(api_key=g_key)
# create dataframe with lat, lng and Humidity
locations = weather_data[["Lat","Lng"]]
humidity = weather_data["Humidity"]

# %%
# create intial gmap figure
fig = gmaps.figure()
# add heatmap layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=100, point_radius=0.9)
# add heatmap layer to figure
fig.add_layer(heatmap_layer)
# Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_weather = weather_data[(weather_data["Humidity"] > 70) & (weather_data["Humidity"] <= 75)]
ideal_weather = ideal_weather.dropna()
ideal_weather
# Out:
#                           City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 41                  Butaritari   3.07  172.79     83.35        71         100
# 54              Cabo San Lucas  22.89 -109.91     87.80        74          40
# 64       Los Llanos de Aridane  28.66  -17.92     77.00        73          75
# 117                   Mollendo -17.02  -72.01     62.10        71          89
# 125         Acapulco de Juárez  16.86  -99.89     86.00        74          75
# 145                   Saldanha -33.01   17.94     51.80        71          89
# 159                  Grenville  12.12  -61.62     87.80        74          40
# 176               Puerto Limón  10.00  -83.03     86.00        74          75
# 185                   Hokitika -42.72  170.97     50.11        71          99
# 192                       Fare -16.70 -151.02     78.91        73          10
# 194                     Faanui -16.48 -151.75     78.21        74           0
# 207                       Jadu  31.95   12.03     70.74        71          49
# 230                Broken Hill -31.95  141.43     50.00        71           0
# 259                      Pisco -13.70  -76.22     68.00        72          98
# 330                    Sibolga   1.74   98.78     76.82        74          57
# 335                       Ayan  56.45  138.17     59.81        74         100
# 355            Plettenberg Bay -34.05   23.37     54.59        71          47
# 375                     Padang  -0.95  100.35     78.24        74         100
# 433                      Sidhi  24.42   81.88     81.27        71          14
# 447                     Hirara  24.80  125.28     82.87        71          95
# 488                     Kigoma  -4.88   29.63     77.00        73           5
# 530                     Playas  -2.63  -80.38     74.80        74          18
# 547                 Mugur-Aksy  50.35   90.50     36.59        74          58
# 552           Coahuayana Viejo  18.73 -103.68     80.60        74          40
# 556            Havre-St-Pierre  50.23  -63.60     53.60        71           1
# 558                     Lékoni  -1.58   14.26     77.36        73         100
# 563                   Tevaitoa -16.78 -151.50     79.25        72           6
#
#          Wind Speed Country        Date
# City_ID
# 41            19.46      KI  1600109751
# 54             4.70      MX  1600109679
# 64             6.93      ES  1600109758
# 117            5.84      PE  1600109773
# 125            3.36      MX  1600109547
# 145            5.82      ZA  1600109781
# 159           11.41      GD  1600109595
# 176            5.82      CR  1600109616
# 185           20.04      NZ  1600109791
# 192           11.27      PF  1600109793
# 194           11.36      PF  1600109794
# 207            8.12      LY  1600109799
# 230            5.82      AU  1600109805
# 259            9.17      PE  1600109816
# 330            3.29      ID  1600109839
# 335            6.38      RU  1600109840
# 355           10.80      ZA  1600109841
# 375            4.03      ID  1600109852
# 433            1.77      IN  1600109870
# 447            7.54      JP  1600109876
# 488            4.09      TZ  1600109888
# 530           15.37      EC  1600109900
# 547            0.83      RU  1600109906
# 552            6.02      MX  1600109908
# 556           27.51      CA  1600109884
# 558            6.87      GA  1600109910
# 563           10.71      PF  1600109911

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# store ideal_weather dataframe as hotel_df
hotel_df = ideal_weather.astype(str)
# add empty Hotel Name column to dataframe
hotel_df["Hotel Name"] = ""

# set base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

# parameter variables hotels within 5000 meters
for index,row in hotel_df.iterrows():
    try:
        location = row[str("Lat")] + "," + row[str("Lng")]
        request_url = base_url + "location=" + location + "&radius=5000" + "&type=lodging" + "&key=" + g_key
        response = requests.get(request_url).json()
        hotel_name = response["results"][0]["name"]
        row["Hotel Name"] = hotel_name
    except IndexError:
        row["Hotel Name"] = "**No hotel within 5000 meters**"

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
locations = locations.astype(float)
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
